# %%
import pandas as pd

# %%
data = pd.Series(list(range(10, 1001)))

# %%
print(data.loc[10] + data.loc[23] - data.loc[245] + data.iloc[122])
# Out:
# -70

# %%
data = pd.read_csv('data_sf.xls')

# %%
data
# Out:
#        Unnamed: 0                Name  ...  GKPositioning GKReflexes
# 0               0            L. Messi  ...             14          8
# 1               1   Cristiano Ronaldo  ...             14         11
# 2               2           Neymar Jr  ...             15         11
# 3               3              De Gea  ...             88         94
# 4               4        K. De Bruyne  ...             10         13
# ...           ...                 ...  ...            ...        ...
# 12892       13121        J. Lundstram  ...              8          9
# 12893       13122  N. Christoffersson  ...              5         12
# 12894       13123           B. Worman  ...              6         13
# 12895       13124      D. Walker-Rice  ...              8          9
# 12896       13125           G. Nugent  ...             12          9
#
# [12897 rows x 42 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
data.info()['Dtype']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0           Age  ...  GKPositioning    GKReflexes
# count  12897.000000  12897.000000  ...   12897.000000  12897.000000
# mean    6605.040862     24.795379  ...      16.950221     17.315965
# std     3782.545526      4.872212  ...      17.369297     18.335817
# min        0.000000     16.000000  ...       1.000000      1.000000
# 25%     3357.000000     21.000000  ...       8.000000      8.000000
# 50%     6622.000000     24.000000  ...      11.000000     11.000000
# 75%     9876.000000     28.000000  ...      14.000000     14.000000
# max    13125.000000     45.000000  ...      90.000000     94.000000
#
# [8 rows x 38 columns]

# %%
data.describe(include=['object'])
# Out:
#                 Name Nationality             Club Position
# count          12897       12897            12897    12897
# unique         12326         156              650       27
# top     J. Rodríguez     England  Shonan Bellmare       GK
# freq               9        1368               30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(data.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
data['ShortPassing'].describe()
# Out:
# count    12897.000000
# mean        56.026983
# std         14.740436
# min          7.000000
# 25%         50.000000
# 50%         60.000000
# 75%         65.000000
# max         93.000000
# Name: ShortPassing, dtype: float64

# %%
data['Club'].describe()
# Out:
# count               12897
# unique                650
# top       Shonan Bellmare
# freq                   30
# Name: Club, dtype: object

# %%
data['Position'].describe()
# Out:
# count     12897
# unique       27
# top          GK
# freq       1641
# Name: Position, dtype: object

# %%
data.Age.mean()
# Out:
# 24.795378770256647

# %%
data.Composure.isnull().sum()
# Out:
# 0

# %%
data.ShortPassing.std()
# Out:
# 14.740435689517149

# %%
data.Wage.sum()
# Out:
# 96954000

# %%
data.Value.min()
# Out:
# 0

# %%
data[(data.Age < data.Age.mean())&
        (data.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
data[data.Wage < data.Wage.mean()].SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
data[data.Wage == data.Wage.max()].Position
# Out:
# 0    RF
# Name: Position, dtype: object

# %%
data[data.Nationality == 'Brazil'].Penalties.sum()
# Out:
# 22789

# %%
round(data[data.HeadingAccuracy > 50].Age.mean(), 2)
# Out:
# 25.59

# %%
data[(data.Composure > data.Composure.max() * 0.9) & (data.Reactions > data.Reactions.max() * 0.9)].Age.min()
# Out:
# 24

# %%
data[data.Age == data.Age.max()].Reactions.mean() - data[data.Age == data.Age.min()].Reactions.mean()
# Out:
# 22.642857142857146

# %%
data[data.Value > data.Value.mean()].Nationality.describe()
# Out:
# count      1747
# unique       98
# top       Spain
# freq        211
# Name: Nationality, dtype: object

# %%
data[(data.Position == 'GK')&(data.GKReflexes == data.GKReflexes.max())].Wage.mean() / data[(data.Position == 'GK')&(data.GKHandling == data.GKHandling.max())].Wage.mean()
# Out:
# 2.765957446808511

# %%
data[data.Aggression == data.Aggression.max()].ShotPower.mean() / data[data.Aggression == data.Aggression.min()].ShotPower.mean()
# Out:
# 2.076923076923077
